# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import datetime as dt
from matplotlib import pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

from ipywidgets import interact, interactive, fixed, interact_manual
from IPython import display
# %matplotlib notebook

def Leapyear (year):
    if year % 4 == 0:
        s = 1
    else:
        s = 0
    return s

def months (year):
    if Leapyear(year) == 0:
        months = np.asarray([1,32,60,91,121,152,182,213,244,274,305,335,366])
    else:
        months = np.asarray([1,32,61,92,122,153,183,214,245,275,306,336,367])
    return months

def doy2dat (doy,yyyy):
    ni = np.min([doy.shape,yyyy.shape])
    ret = np.zeros(shape=(2,ni))
    for i in range(0,ni):
        first_of_month=months(yyyy[i])
        lower_mon=np.where(first_of_month<doy[i])[0]
        ret[0,i]=lower_mon.shape[0]
        ret[1,i]=doy[i]-(first_of_month[int(ret[0,i]-1)]-1)
    return(ret)

def DT (doy,yyyy,hrmn,sec):
    s = doy2dat(doy,yyyy)
    i = 0
    Temp = []
    for m in hrmn:
        hr = str(m)[:2]
        mn = str(m)[2:]
        Z = str(yyyy[i])+'-'+str(int(s[0,i]))+'-'+str(int(s[1,i]))+' '+hr+':'+mn+':'+str(sec[i])
        Temp.append(Z)
        i += 1
    Temp = pd.to_datetime(np.asarray(Temp))
    return(Temp)

Path = 'C:/FishIsland_2017/ChamberStationData/6_22.DAT'
# Path = 'C:/FishIsland_2017/ChamberStationData/DATA034.DAT'
Data = pd.read_csv(Path,delimiter = ',',header = None,na_values = -9999)
if Data[3].min()<1000:
    Data[3]+=1000
Data['Datetime']=pd.DatetimeIndex(DT(Data[2],Data[1],Data[3],Data[4]))#Data.index
Data['co2'] = Data[8]
Data['RH'] = Data[10]

# %%
# %matplotlib inline

class Flux_Calc:
    def __init__(self,Data):
        self.Colors = ['red','blue','green','yellow','orange','purple','cyan','black','brown','pink','magenta']
        self.Data = Data
    def Time_Break(self):
        self.Data['co2'][0] = np.nan
        for i in range(1,self.Data.index.shape[0]-1):
            if (str(self.Data.index[i+1]-self.Data.index[i])[-1])!='1':
                self.Data['co2'][i]=np.nan
        splits = pd.isnull(self.Data).any(1).nonzero()[0]
        self.Samples = np.split(Data,splits[1:],axis=0)
        i = 0
        for samp in self.Samples:
            self.Samples[i]=samp[-120:]
            i +=1
        self.N = i
    def Break(self):
        self.Data['co2_diff'] = self.Data['co2'].diff()
        self.Data.loc[self.Data['co2_diff']<-5,['co2']]=np.nan
        splits = pd.isnull(self.Data).any(1).nonzero()[0]
        self.Samples = np.split(Data,splits[1:],axis=0)
        Samples=[]
        i = 0
        x1,x2=0,-1
        x1,x2,x3=0,-1,''
        self.Slices = []
        self.depth=[]
        self.fig,self.ax = plt.subplots(nrows = 1,ncols = 1,figsize = (5,5))
        self.samp = self.Samples[i]
        self.ax.plot(self.samp['co2'])
#         display.display(plt.gcf())
        
#         print(self.samp.index.max())
        
        self.x1 = interact(self.SlideRight,x=(0,102))
# # #         self.x2 = interact(self.SlideLeft,x=(1,20))
        
    def SlideRight(self,x):
        Slice = self.samp[x:-1]
        display.clear_output(wait=True) 
#         plt.figure()
        try:
            self.udate.remove()
        except:
            pass
        self.udate, = self.ax.plot(Slice['co2'],color='green')
#         self.ax.set_xlim(0,10)
#         print(Slice['co2'])
        return(x)
    
#     def Udate(self):
#         d

Flux = Flux_Calc(Data)
Flux.Break()
# plt.show()
# plt.figure(figsize = (12,8))
# X=np.arange(0,100,.1)
# plt.plot(X,np.sin(X))
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.1499846283103">
# A Jupyter Widget

# %%
from ipywidgets import Button, Layout

class Module:
    def __init__(self,Data):
        self.Data = Data
        self.x1 = self.Data.index.min()
        self.x2 = self.Data.index.max()
        self.fig,self.ax = plt.subplots(nrows = 1,ncols = 1,figsize = (5,5))
        self.ax.plot(Data['co2'],color='grey')
        interact(self.SlideLeft,x=(0,self.Data.index.max()))
        interact(self.SlideRight,x=(0,self.Data.index.max()))
        Save = Button(description='(50% width, 80px height) button',
           layout=Layout(width='50%', height='80px'))
        display(Save)
        Save.on_click(self.Clear)
        
#         interact(self.Clear, x=False)
    def SlideLeft(self,x):
        Slice = self.Data[x:self.x2]
        try:
            self.udate.remove()
        except:
            pass
        self.udate, = self.ax.plot(Slice['co2'],color='green')
        self.x1 = x
        return(x)
    def SlideRight(self,x):
        Slice = self.Data[self.x1:x]
        try:
            self.udate.remove()
        except:
            pass
        self.udate, = self.ax.plot(Slice['co2'],color='green')
        self.x2 = x
        return(x)
    def Clear(self,b):
        print('button')
#         if x == True:
        plt.gcf().clear()
#         self.__init__
# #             plt.plot(self.Data['co2'],color='red')
#         print(x)

# print(Flux.Samples[0])
# for i in range(2):

Files = ['6_22.DAT','7_10.DAT','8_21.DAT']

def Assign(x):
    return(x)
V = str(interact(Assign,x='0'))
print(V)

Mod = Module(Flux.Samples[0])
# Save = Button(description='(50% width, 80px height) button',
#            layout=Layout(width='50%', height='80px'))
# display(Save)
# Save.on_click(Mod.Clear(1))


# C = input('Continue')
# if C == 'C':
#     display.clear_output(wait=True)
# Out:
# A Jupyter Widget
# <function Assign at 0x0000022392826D90>
# <div id='7b37c5d7-c397-4c87-aab7-b45d833d26e6'></div>
# A Jupyter Widget
# A Jupyter Widget
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f32018a5df00> in <module>()
#      53 print(V)
#      54
# ---> 55 Mod = Module(Flux.Samples[0])
#      56 # Save = Button(description='(50% width, 80px height) button',
#      57 #            layout=Layout(width='50%', height='80px'))
#
# <ipython-input-4-f32018a5df00> in __init__(self, Data)
#      13         Save = Button(description='(50% width, 80px height) button',
#      14            layout=Layout(width='50%', height='80px'))
# ---> 15         display(Save)
#      16         Save.on_click(self.Clear)
#      17
#
# TypeError: 'module' object is not callable

# %%
from IPython.display import display
import ipywidgets as widgets
button = widgets.Button(description="Click Me!")
display(button)

def on_button_clicked(b,x):
#     print(b)
    print(x)
    print("Button clicked.")

button.on_click(on_button_clicked(button,x=1))
#     def SlideLeft(self,x):
#         Slice = self.samp[0:x]
#         self.ax.plot(Slice['co2'],color='red')
#         return(x)
        
        
#         for samp in self.Samples:
#             samp = samp.reset_index()
#             print(x3)
#             if samp['co2'].shape[0]> 100 and x3 =='':
#                 fig,ax = plt.subplots(nrows = 1,ncols = 1,figsize = (10,10))
#                 ax.plot(samp['co2'])
                
                
#                 display.display(plt.gcf())
#                 x1 = int(input('Start'))
#                 x2 = int(input('Stop'))
#                 d = int(input('Depth'))
#                 self.depth.append(d)

#                 self.Slices.append(samp[x1:x2])
#                 display.clear_output(wait=True) 
            
#                 x3 = input("Enter to Continue Type Any Key to quit")
# #               
#                 i +=1
#         self.N = i
#         plt.close('all')
#         display.clear_output(wait=True) 
#         fyg,ayx = plt.subplots(nrows = 1,ncols = 1,figsize = (14,14))
#         self.Calc_Flux()
#         i = 0
#         for samp in self.Slices:
#             ayx.plot(samp['Datetime'],samp['co2'],color='grey')
#             ayx.plot(samp['Datetime'],samp['Modeled'],color = self.Colors[i],linestyle = '--',
#                      label='Collar '+ str(i)+' '+ str(np.round(self.Fluxes[i],2)))
#             i+=1
#         plt.legend()
#     def Rho(self,T,RH,P):
#         p_sat = 6.1078*10**(7.5*T/(T+237.3))
#         p_v = RH*p_sat
#         p_d = P-p_v
#         R_Dry = 8.314
#         self.rho = (p_d*0.028964+p_v*0.018016)/(R_Dry*T)
#     def Calc_Flux(self):
#         area = 0.0079 # area in m2
#         molar_mass = 0.0289644 # kg/mol
        
#         self.Rho(10,65,1010)
#         molar_density = self.rho / molar_mass
        
#         model = make_pipeline(PolynomialFeatures(1), Ridge(alpha = 0))
#         i = 0
#         self.Coefs = np.zeros(shape = self.N)
#         self.Fluxes = []
#         for samp in self.Slices:
            
#             extra_volume = float(self.depth[i]) * 0.01 * area
#             volume = 0.0014 + extra_volume # volume in m3
            
#             self.Slices[i] = self.Slices[i].reset_index(drop=True)
#             self.Slices[i] = self.Slices[i].dropna()
#             X =self.Slices[i].index.values.reshape(self.Slices[i].index.shape[0],1)
#             y = self.Slices[i]['co2'].values.reshape(self.Slices[i].index.shape[0],1)
#             model.fit(X,y)
#             self.Coefs[i]=(model.steps[1][1].coef_[0][1])
#             print(model.steps[1][1].coef_)
#             self.Slices[i]['Modeled'] = model.predict(X)
#             flux = molar_density * volume * self.Coefs[i] / area
#             self.Fluxes.append(flux)
#             i+=1
#         print (self.Coefs)
# Out:
# A Jupyter Widget
# 1
# Button clicked.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: 'NoneType' object is not callable

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

class PlotStuff:
    def __init__(self):
        
        self.fig,self.ax = plt.subplots(nrows = 1,ncols = 1,figsize = (10,10))
        
        X = np.arange(0,100,.5)
        self.ax.plot(X,np.sin(X))
        xm = interact(self.f,x=(0.0,20.0,0.5))
        print('kitty')
        plt.show()
        
    def f(self,x):
        X = np.arange(0,x)
        self.ax.plot(X,np.cos(X))
        return(x)



# plt.figure()

X = PlotStuff()
print(X)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import display, clear_output
import ipywidgets as widgets

# plot func
fig, ax = plt.subplots()
plt.close(fig)

t = np.arange(0.0, 1.0, 0.001)
x = np.linspace(0.0, 2.0, 1000)
s = x*np.pi*t

def sinePlot(f):
    ax.clear()
    ax.plot(x, np.sin(s*f))
    display(fig)

mySlider = widgets.FloatSlider(value=0.5, min=0.1, max=1, step=0.1, description=('Slider'))

# initial plot
sinePlot(f=1.0)

# on slider change
def on_slider_change(change):
    clear_output(wait=True)
    print(change)
    sinePlot(change['new'])
    display(mySlider)
    
mySlider.observe(on_slider_change, names='value')
display(mySlider)

# %%
mySlider.observe(on_slider_change, names='value')
display(mySlider)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import display, clear_output
import ipywidgets as widgets

fig, ax = plt.subplots()
plt.close(fig)

t = np.arange(0.0, 1.0, 0.001)
x = np.linspace(0.0, 2.0, 1000)
s = x*np.pi*t

def sinePlot(f):
    ax.clear()
    ax.plot(x, np.sin(s*f))
    ax.set_ylim([-1, 1])
    ax.set_title('slider/100 = {:.2f}'.format(f))
    display(fig)

def g(x):
    return x/100.0
    

slider = widgets.IntSlider(value=50, min=2, max=100, step=2, description=('slider'))
play = widgets.Play(value=50)
widgets.jslink((play, 'value'), (slider, 'value'))

def on_slider_change(change):
    clear_output(wait=True)
    sinePlot(g(change['new']))
slider.observe(on_slider_change, names='value')

def on_player_change(change):
    print(change['new'])
play.observe(on_player_change, names='value')

box = widgets.VBox([play, slider])

sinePlot(f=g(slider.value))
display(box)
